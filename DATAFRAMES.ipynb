# %% [markdown]
# ### DATA FRAMES

# %% [markdown]
# ### Creating Dataframes

# %%
import pandas as pd

# %% [markdown]
# ### From Dictionary

# %%
dict1={'Age':[25,25,32,23,27,26,22,22,24,32,28,24,23,25,26,23,25,25,31,21,21],
       'Name':['Rinto','Joyal Joseph','Saneesh Mathew','Aswathy M V','Raneesh V U','Viswanth V','Reshma Reghunath','Doniya','Adarsh Balan','SURAJ S B','Sreelekhmi K S','Anantha krishnan T','Aiswarya George','Reshma A C','Sirajudheen T M','Vaishakh V V','Biben Johnson','Arun','Reshmi R Nair','Shaijal','Christy James'],
      'Gender':['Male','Male','Male','Female','Male','Male','Female','Female','Male','Male','Female','Male','Female','Female','Male','Male','Male','male','Female','Male','Male'],
      'Qualification':['Btech','Bsc Mathematics','Bsc CS','Btech','Bsc Cs','Btech','BCA','Btech','Btech','B com','MCA','Btech','MSC Statitics','MSC Maths','M com','BBA','Btech','MBA','MBA','Bsc','BE Cse'],
      'Place':['Palakkad','Pala','Kasargod','Kannur','Thrissur','Adoor','Pathanamathitta','Idukki','Kayamkulam','Kottarakara','Chengannur','Kollam','Ernakulam','Thrissur','Malappuram','Malappuram','Kollam','Alappuzha','Thiruvalla','Malappuram','Wayanad']}

# %%
data1=pd.DataFrame(dict1)

# %%
data1
# Out:
#     Age                Name  Gender    Qualification            Place
# 0    25               Rinto    Male            Btech         Palakkad
# 1    25        Joyal Joseph    Male  Bsc Mathematics             Pala
# 2    32      Saneesh Mathew    Male           Bsc CS         Kasargod
# 3    23         Aswathy M V  Female            Btech           Kannur
# 4    27         Raneesh V U    Male           Bsc Cs         Thrissur
# 5    26          Viswanth V    Male            Btech            Adoor
# 6    22    Reshma Reghunath  Female              BCA  Pathanamathitta
# 7    22              Doniya  Female            Btech           Idukki
# 8    24        Adarsh Balan    Male            Btech       Kayamkulam
# 9    32           SURAJ S B    Male            B com      Kottarakara
# 10   28      Sreelekhmi K S  Female              MCA       Chengannur
# 11   24  Anantha krishnan T    Male            Btech           Kollam
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            21 non-null     int64
#  1   Name           21 non-null     object
#  2   Gender         21 non-null     object
#  3   Qualification  21 non-null     object
#  4   Place          21 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 968.0+ bytes

# %% [markdown]
# ### DataFrame using Lists

# %%
Age=[25,25,32,23,27,26,22,22,24,32,28,24,23,25,26,23,25,25,31,21,21]
Names=['Rinto','Joyal Joseph','Saneesh Mathew','Aswathy M V','Raneesh V U','Viswanth V','Reshma Reghunath','Doniya','Adarsh Balan','SURAJ S B','Sreelekhmi K S','Anantha krishnan T','Aiswarya George','Reshma A C','Sirajudheen T M','Vaishakh V V','Biben Johnson','Arun','Reshmi R Nair','Shaijal','Christy James']
Gender=['Male','Male','Male','Female','Male','Male','Female','Female','Male','Male','Female','Male','Female','Female','Male','Male','Male','male','Female','Male','Male']
Qualification=['Btech','Bsc Mathematics','Bsc CS','Btech','Bsc Cs','Btech','BCA','Btech','Btech','B com','MCA','Btech','MSC Statitics','MSC Maths','M com','BBA','Btech','MBA','MBA','Bsc','BE Cse']
Place=['Palakkad','Pala','Kasargod','Kannur','Thrissur','Adoor','Pathanamathitta','Idukki','Kayamkulam','Kottarakara','Chengannur','Kollam','Ernakulam','Thrissur','Malappuram','Malappuram','Kollam','Alappuzha','Thiruvalla','Malappuram','Wayanad']

# %%
data1=pd.DataFrame(list(zip(Age,Names,Gender,Qualification,Place)),columns=['AGE','NAME','GENDER','QUALIFICATION','PLACE'])

# %%
data1
# Out:
#     AGE                NAME  GENDER    QUALIFICATION            PLACE
# 0    25               Rinto    Male            Btech         Palakkad
# 1    25        Joyal Joseph    Male  Bsc Mathematics             Pala
# 2    32      Saneesh Mathew    Male           Bsc CS         Kasargod
# 3    23         Aswathy M V  Female            Btech           Kannur
# 4    27         Raneesh V U    Male           Bsc Cs         Thrissur
# 5    26          Viswanth V    Male            Btech            Adoor
# 6    22    Reshma Reghunath  Female              BCA  Pathanamathitta
# 7    22              Doniya  Female            Btech           Idukki
# 8    24        Adarsh Balan    Male            Btech       Kayamkulam
# 9    32           SURAJ S B    Male            B com      Kottarakara
# 10   28      Sreelekhmi K S  Female              MCA       Chengannur
# 11   24  Anantha krishnan T    Male            Btech           Kollam
# ...

# %% [markdown]
# ### DataFrame from Lists of Dictionaries

# %%
lst=[
    {'Name': 'Rinto'              ,'Age':25   ,'Gender':'Male',    'Qualification':'Btech',          'Place':'Palakkad'},
    {'Name': 'Joyal Joseph'       ,'Age':25   ,'Gender':'Male',    'Qualification':'Bsc Mathematics','Place':'Pala'},
    {'Name': 'Saneesh Mathew'     ,'Age':32   ,'Gender':'Male',    'Qualification':'Bsc CS'      ,'Place':'Kasargod'    },
    {'Name': 'Aswathy M V'        ,'Age': 23  ,'Gender':'Female',  'Qualification':'Btech'      ,'Place':'Kannur'   },
    {'Name': 'Raneesh V U'        ,'Age':27   ,'Gender':'Male'   ,  'Qualification':'Bsc Cs'     ,'Place': 'Thrissur'   },
    {'Name': 'Viswanth V'         ,'Age':26   ,'Gender':'Male'   ,  'Qualification': 'Btech'     ,'Place':'Adoor'    },
    {'Name': 'Reshma Reghunath'   ,'Age':22   ,'Gender':'Female'   ,'Qualification':'BCA'      ,'Place':'Pathanamathitta'    },
    {'Name': 'Doniya'             ,'Age':22   ,'Gender':'Female'   ,'Qualification':'Btech'      ,'Place':'Idukki'    },
    {'Name': 'Adarsh Balan'       ,'Age':24   ,'Gender':'Male'   ,  'Qualification':'Btech'       ,'Place':'Kayamkulam'    },
    {'Name': 'SURAJ S B'          ,'Age':32   ,'Gender':'Male'  ,   'Qualification':'B com'      ,'Place':'Kottarakara'    },
    {'Name': 'Sreelekhmi K S'     ,'Age':28   ,'Gender':'Female'   ,'Qualification':'MCA'      ,'Place':'Chengannur'   },
    {'Name': 'Anantha krishnan T' ,'Age':24   ,'Gender':'Male'   ,  'Qualification':'Btech'       ,'Place':'Kollam'    },
    {'Name': 'Aiswarya George'    ,'Age':23   ,'Gender': 'Female'  ,'Qualification':'MSC Statitics'      ,'Place':'Ernakulam'    },
    {'Name': 'Reshma A C'         ,'Age':25   ,'Gender':'Female'   ,'Qualification':'MSC Maths'      ,'Place':'Thrissur'    },
    {'Name': 'Sirajudheen T M'    ,'Age':26   ,'Gender':'Male'    , 'Qualification':'M com'      ,'Place':'Malappuram'    },
    {'Name': 'Vaishakh V V'       ,'Age':23   ,'Gender':'Male'   ,  'Qualification':'BBA'      ,'Place':'Malappuram'    },
    {'Name': 'Biben Johnson'      ,'Age':25   ,'Gender':'Male'   ,  'Qualification':'Btech'      ,'Place':'Kollam'    },
    {'Name': 'Arun'               ,'Age':25   ,'Gender':'Male'   ,  'Qualification':'MBA'      ,'Place':'Alappuzha'    },
    {'Name': 'Reshmi R Nair'      ,'Age':31   ,'Gender':'Female',   'Qualification':'MBA'      ,'Place':'Thiruvalla'    },
    {'Name': 'Shaijal'            ,'Age':21   ,'Gender':'Male',     'Qualification':'Bsc'      ,'Place':'Malappuram'    },
    {'Name': 'Christy James'      ,'Age':21   ,'Gender':'Male' ,    'Qualification':'BE Cse'      ,'Place':'Wayanad'    },
    ]

# %%
data1=pd.DataFrame(lst)

# %%
data1
# Out:
#                   Name  Age  Gender    Qualification            Place
# 0                Rinto   25    Male            Btech         Palakkad
# 1         Joyal Joseph   25    Male  Bsc Mathematics             Pala
# 2       Saneesh Mathew   32    Male           Bsc CS         Kasargod
# 3          Aswathy M V   23  Female            Btech           Kannur
# 4          Raneesh V U   27    Male           Bsc Cs         Thrissur
# 5           Viswanth V   26    Male            Btech            Adoor
# 6     Reshma Reghunath   22  Female              BCA  Pathanamathitta
# 7               Doniya   22  Female            Btech           Idukki
# 8         Adarsh Balan   24    Male            Btech       Kayamkulam
# 9            SURAJ S B   32    Male            B com      Kottarakara
# 10      Sreelekhmi K S   28  Female              MCA       Chengannur
# 11  Anantha krishnan T   24    Male            Btech           Kollam
# ...
